# %%
import xml.etree.ElementTree as Xet
import pandas as pd

cols = ["unique_id", "asin", "product_name", "product_type", "helpful", "rating", 
        "title", "date", "reviewer", "reviewer_location", "review_text"]
rows = []

# Parsing the XML file
xmlparse = Xet.parse('books.xml')
root = xmlparse.getroot()
for i in root:
    unique_id = i.find("unique_id").text
    asin = i.find("asin").text
    product_name = i.find("product_name").text
    product_type = i.find("product_type").text
    helpful = i.find("helpful").text
    rating = i.find("rating").text
    title = i.find("title").text
    date = i.find("date").text
    reviewer = i.find("reviewer").text
    reviewer_location = i.find("reviewer_location").text
    review_text = i.find("review_text").text


    rows.append({"unique_id": unique_id,
                 "asin": asin,
                 "product_name": product_name,
                 "product_type": product_type,
                 "helpful": helpful,
                 "rating": rating,
                 "title": title,
                 "date": date,
                 "reviewer": reviewer,
                 "reviewer_location": reviewer_location,
                 "review_text": review_text
                })

df = pd.DataFrame(rows, columns=cols)

# Writing dataframe to csv
df.to_csv('books.csv')

# %%
df.head()
# Out:
#                                            unique_id            asin  \
# 0  \n1884956068:a_mainstay_reference_for_spanish-...  \n1884956068\n
# 1  \n0679728740:you_want_the_necrophiliac_to_esca...  \n0679728740\n
# 2  \n0679728740:low_brow_and_juvenile:bruce_miller\n  \n0679728740\n
# 3  \n0679728740:mccarthy,_a_brave_writer_with_an_...  \n0679728740\n
# 4  \n0679728740:sevierville_in_child_of_god:alex_...  \n0679728740\n
#
#                                         product_name product_type  \
# 0  \nManual pedi�trico para los due�os del nuevo ...    \nbooks\n
# 1           \nChild of God: Books: Cormac Mccarthy\n    \nbooks\n
# 2           \nChild of God: Books: Cormac Mccarthy\n    \nbooks\n
# 3           \nChild of God: Books: Cormac Mccarthy\n    \nbooks\n
# 4           \nChild of God: Books: Cormac Mccarthy\n    \nbooks\n
#
#         helpful   rating                                              title  \
# ...

# %%
df['review_text'][0]
# Out:
# "\nThis all-Spanish handbook for parents with new babies will prove essential for any concerned about a child's health. Manual Pediatrico appeared first in English; the Spanish edition provides essential health information at a glance for parents unversed in medical care; and should be a mainstay of  any Spanish-speaking home with children\n"

# %%
df.dtypes
# Out:
# unique_id            object
# asin                 object
# product_name         object
# product_type         object
# helpful              object
# rating               object
# title                object
# date                 object
# reviewer             object
# reviewer_location    object
# review_text          object
# dtype: object

# %%
df['unique_id']=df['unique_id'].apply(str).str.replace('\n','')
df['asin']=df['asin'].apply(str).str.replace('\n','')
df['product_name']=df['product_name'].apply(str).str.replace('\n','')
df['product_type']=df['product_type'].apply(str).str.replace('\n','')
df['helpful']=df['helpful'].apply(str).str.replace('\n','')
df['rating']=df['rating'].apply(str).str.replace('\n','')
df['title']=df['title'].apply(str).str.replace('\n','')
df['date']=df['date'].apply(str).str.replace('\n','')
df['reviewer']=df['reviewer'].apply(str).str.replace('\n','')
df['reviewer_location']=df['reviewer_location'].apply(str).str.replace('\n','')
df['review_text']=df['review_text'].apply(str).str.replace('\n','')

# %%
df.head()
# Out:
#                                            unique_id        asin  \
# 0  1884956068:a_mainstay_reference_for_spanish-sp...  1884956068
# 1  0679728740:you_want_the_necrophiliac_to_escape...  0679728740
# 2      0679728740:low_brow_and_juvenile:bruce_miller  0679728740
# 3  0679728740:mccarthy,_a_brave_writer_with_an_in...  0679728740
# 4  0679728740:sevierville_in_child_of_god:alex_jo...  0679728740
#
#                                         product_name product_type   helpful  \
# 0  Manual pedi�trico para los due�os del nuevo be...        books    7 of 8
# 1               Child of God: Books: Cormac Mccarthy        books    0 of 1
# 2               Child of God: Books: Cormac Mccarthy        books    2 of 5
# 3               Child of God: Books: Cormac Mccarthy        books    4 of 5
# 4               Child of God: Books: Cormac Mccarthy        books  11 of 14
#
#   rating                                              title  \
# ...

# %%
df.to_csv('book_dataset.csv', index=False)

# %%
df
# Out:
#                                                unique_id        asin  \
# 0      1884956068:a_mainstay_reference_for_spanish-sp...  1884956068
# 1      0679728740:you_want_the_necrophiliac_to_escape...  0679728740
# 2          0679728740:low_brow_and_juvenile:bruce_miller  0679728740
# 3      0679728740:mccarthy,_a_brave_writer_with_an_in...  0679728740
# 4      0679728740:sevierville_in_child_of_god:alex_jo...  0679728740
# ...                                                  ...         ...
# 41995                  0972894403:that's_it!:terrie_cash  0972894403
# 41996  0972894403:open_your_heart,_open_your_mind:hel...  0972894403
# 41997      0972894403:living_god's_will:patricia_newsome  0972894403
# 41998     0972894403:it_is_a_blessing:michael_abney,_sr.  0972894403
# 41999               0830833900:called_to_monday:r._eberz  0830833900
#
#                                             product_name product_type  \
# ...

# %%
import xml.etree.ElementTree as Xet
import pandas as pd

cols = ["unique_id", "asin", "product_name", "product_type", "helpful", "rating", 
        "title", "date", "reviewer", "reviewer_location", "review_text"]
rows = []

# Parsing the XML file
xmlparse = Xet.parse('positive_review.xml')
root = xmlparse.getroot()
for i in root:
    unique_id = i.find("unique_id").text
    asin = i.find("asin").text
    product_name = i.find("product_name").text
    product_type = i.find("product_type").text
    helpful = i.find("helpful").text
    rating = i.find("rating").text
    title = i.find("title").text
    date = i.find("date").text
    reviewer = i.find("reviewer").text
    reviewer_location = i.find("reviewer_location").text
    review_text = i.find("review_text").text


    rows.append({"unique_id": unique_id,
                 "asin": asin,
                 "product_name": product_name,
                 "product_type": product_type,
                 "helpful": helpful,
                 "rating": rating,
                 "title": title,
                 "date": date,
                 "reviewer": reviewer,
                 "reviewer_location": reviewer_location,
                 "review_text": review_text
                })

df = pd.DataFrame(rows, columns=cols)

# Writing dataframe to csv
df
# Out:
#                                              unique_id            asin  \
# 0    \n0785758968:one_of_the_best_crichton_novels:j...  \n0785758968\n
# 1    \n0452279550:the_medicine_of_the_future:wafa_r...  \n0452279550\n
# 2          \n1599620065:beautiful!:sarah_silva_"sar"\n  \n1599620065\n
# 3    \n0743277724:for_lovers_of_robicheaux:g._rouss...  \n0743277724\n
# 4    \n061318114X:excellent_and_broad_survey_of_the...  \n061318114X\n
# ..                                                 ...             ...
# 995  \n0618256288:interesting_and_educational_and_c...  \n0618256288\n
# 996  \n0152024867:best_book_for_teaching_children_a...  \n0152024867\n
# 997  \n1565843584:fascinating_look_at_america_50_ye...  \n1565843584\n
# 998  \n1580131581:it's_shofar_time!:jewish_book_wor...  \n1580131581\n
# 999        \n0316059625:we_love_this_book!:m._little\n  \n0316059625\n
#
#                                           product_name product_type  \
# ...

# %%
df['unique_id']=df['unique_id'].apply(str).str.replace('\n','')
df['asin']=df['asin'].apply(str).str.replace('\n','')
df['product_name']=df['product_name'].apply(str).str.replace('\n','')
df['product_type']=df['product_type'].apply(str).str.replace('\n','')
df['helpful']=df['helpful'].apply(str).str.replace('\n','')
df['rating']=df['rating'].apply(str).str.replace('\n','')
df['title']=df['title'].apply(str).str.replace('\n','')
df['date']=df['date'].apply(str).str.replace('\n','')
df['reviewer']=df['reviewer'].apply(str).str.replace('\n','')
df['reviewer_location']=df['reviewer_location'].apply(str).str.replace('\n','')
df['review_text']=df['review_text'].apply(str).str.replace('\n','')

# %%
df
# Out:
#                                              unique_id        asin  \
# 0    0785758968:one_of_the_best_crichton_novels:jos...  0785758968
# 1    0452279550:the_medicine_of_the_future:wafa_rashed  0452279550
# 2              1599620065:beautiful!:sarah_silva_"sar"  1599620065
# 3      0743277724:for_lovers_of_robicheaux:g._rousseau  0743277724
# 4    061318114X:excellent_and_broad_survey_of_the_d...  061318114X
# ..                                                 ...         ...
# 995  0618256288:interesting_and_educational_and_chi...  0618256288
# 996  0152024867:best_book_for_teaching_children_abo...  0152024867
# 997  1565843584:fascinating_look_at_america_50_year...  1565843584
# 998  1580131581:it's_shofar_time!:jewish_book_world...  1580131581
# 999            0316059625:we_love_this_book!:m._little  0316059625
#
#                                           product_name product_type   helpful  \
# 0                      Sphere: Books: Michael Crichton        books    0 of 1
# ...

# %%
df.to_csv('positive_review.csv', index=False)

# %%
import xml.etree.ElementTree as Xet
import pandas as pd

cols = ["unique_id", "asin", "product_name", "product_type", "helpful", "rating", 
        "title", "date", "reviewer", "reviewer_location", "review_text"]
rows = []

# Parsing the XML file
xmlparse = Xet.parse('negative_review.xml')
root = xmlparse.getroot()
for i in root:
    unique_id = i.find("unique_id").text
    asin = i.find("asin").text
    product_name = i.find("product_name").text
    product_type = i.find("product_type").text
    helpful = i.find("helpful").text
    rating = i.find("rating").text
    title = i.find("title").text
    date = i.find("date").text
    reviewer = i.find("reviewer").text
    reviewer_location = i.find("reviewer_location").text
    review_text = i.find("review_text").text


    rows.append({"unique_id": unique_id,
                 "asin": asin,
                 "product_name": product_name,
                 "product_type": product_type,
                 "helpful": helpful,
                 "rating": rating,
                 "title": title,
                 "date": date,
                 "reviewer": reviewer,
                 "reviewer_location": reviewer_location,
                 "review_text": review_text
                })

df = pd.DataFrame(rows, columns=cols)

# Writing dataframe to csv
df
# Out:
#                                              unique_id            asin  \
# 0    \n0312355645:horrible_book,_horrible.:mark_gos...  \n0312355645\n
# 1    \n1559278676:shallow_self-indulgence:joseph_s....  \n1559278676\n
# 2    \n1559278676:horrible_book,_horrible.:mark_gos...  \n1559278676\n
# 3        \n0425193373:disappointment:reader_"reader"\n  \n0425193373\n
# 4          \n0142004030:a_disappointing_mess:a._ross\n  \n0142004030\n
# ..                                                 ...             ...
# 995  \n0385514573:a_nice_place_to_visit....:nina_sh...  \n0385514573\n
# 996                  \n0385514573:boring:o._gonzalez\n  \n0385514573\n
# 997      \n097160200X:lacking:m._roman_"matt1234567"\n  \n097160200X\n
# 998  \n1564147363:okay_for_ideas:stacy_e._burrell_"...  \n1564147363\n
# 999  \n0312273193:it's_just_"reefer_madness"_:r._jo...  \n0312273193\n
#
#                                           product_name product_type  \
# ...

# %%
df['unique_id']=df['unique_id'].apply(str).str.replace('\n','')
df['asin']=df['asin'].apply(str).str.replace('\n','')
df['product_name']=df['product_name'].apply(str).str.replace('\n','')
df['product_type']=df['product_type'].apply(str).str.replace('\n','')
df['helpful']=df['helpful'].apply(str).str.replace('\n','')
df['rating']=df['rating'].apply(str).str.replace('\n','')
df['title']=df['title'].apply(str).str.replace('\n','')
df['date']=df['date'].apply(str).str.replace('\n','')
df['reviewer']=df['reviewer'].apply(str).str.replace('\n','')
df['reviewer_location']=df['reviewer_location'].apply(str).str.replace('\n','')
df['review_text']=df['review_text'].apply(str).str.replace('\n','')

# %%
df.to_csv('negative_review.csv', index=False)

# %%
import pandas as pd

# %%
df=pd.read_csv("books.csv")

# %%
df
# Out:
#        Unnamed: 0                                          unique_id  \
# 0               0  \n1884956068:a_mainstay_reference_for_spanish-...
# 1               1  \n0679728740:you_want_the_necrophiliac_to_esca...
# 2               2  \n0679728740:low_brow_and_juvenile:bruce_miller\n
# 3               3  \n0679728740:mccarthy,_a_brave_writer_with_an_...
# 4               4  \n0679728740:sevierville_in_child_of_god:alex_...
# ...           ...                                                ...
# 41995       41995              \n0972894403:that's_it!:terrie_cash\n
# 41996       41996  \n0972894403:open_your_heart,_open_your_mind:h...
# 41997       41997  \n0972894403:living_god's_will:patricia_newsome\n
# 41998       41998  \n0972894403:it_is_a_blessing:michael_abney,_s...
# 41999       41999           \n0830833900:called_to_monday:r._eberz\n
#
#                  asin                                       product_name  \
# ...

# %%
df['product_type'].unique(0)
# Out:
# <bound method Series.unique of 0        \nbooks\n
# 1        \nbooks\n
# 2        \nbooks\n
# 3        \nbooks\n
# 4        \nbooks\n
#            ...
# 41995    \nbooks\n
# 41996    \nbooks\n
# 41997    \nbooks\n
# 41998    \nbooks\n
# 41999    \nbooks\n
# Name: product_type, Length: 42000, dtype: object>
